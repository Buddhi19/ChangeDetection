# %% [markdown]
# # State Space Models

# %% [markdown]
# Time Domain
# $$
# \begin{align*}
# h'(t) &= A h(t) + Bu(t)\\
# y(t) &= C h(t)
# \end{align*}
# $$
# Discrete Time Domain
# \begin{align*}
# h_{k+1} &= A h_k + Bu_k\\
# y_k &= C h_k
# \end{align*}

# %% [markdown]
# Discretization
# $$
# \begin{align*}
# \bar{A} &= exp(\Delta A)\\
# \bar{B}& = (\Delta A)^{-1} (exp(\Delta A)-I).\Delta B
# \end{align*}
# $$

# %% [markdown]
# $\Delta$ Modifies weights in A,B,C matrices

# %% [markdown]
# Updates Hidden State as,
# $$
# \begin{align*}
# h_t &= \bar{A}h_{t-1}+\bar{B}U_t\\
# y_t &= Ch_t
# \end{align*}
# $$

# %% [markdown]
# Changing $\Delta$ (Step Size) makes model to learn only important information

# %% [markdown]
# Linear RNNs
#
# $$
# \begin{align*}
# h_1 &= \bar{A}h_0+\bar{B}u_1\\
# y_1 &= Ch_1
# \end{align*}
# $$
# Thus,
# $$
# \begin{align*}
# h_t &= \bar{A}^t h_0 + \sum_{k=1}^{t} \bar{A}^{t-k} \bar{B} u_k \\
# y_t &= C h_t
# \end{align*}
# $$
# With 0 initial conditions,
# $$
# \begin{align*}
# h_0 &= \bar{B}u_0\\
# h_t &= \sum_{k=0}^{t} \bar{A}^{t-k} \bar{B} u_k \\
# y_t &= Ch_t
# \end{align*}
# $$
# If sequence length is $L$,
# $$
# \begin{align*}
# K &= [\bar{A}^{L-1}\bar{B},...,\bar{A}\bar{B},\bar{B}] \\
# U &= [u_0,u_1,...,u_{L-1}]
# \end{align*}
# $$
# Since K is not time Varying,
# $$
# \begin{align*}
# h_t &= K*U\\
# y_t &= CK*U
# \end{align*}
# $$

# %% [markdown]
# ## Selective SSMs
# $$
# \begin{align*}
# h_t &= \bar{A}^t h_0 + \sum_{k=1}^{t} \bar{A}^{t-k} \bar{B}_k u_k \\
# y_t &= C_t h_t
# \end{align*}
# $$
# Where now we have a time varying kernal $K(t,k)$

# %% [markdown]
# $$
# \begin{align*}
# h_t &= \sum_{k=0}^{t} \bar{A}^{t-k} \bar{B}_k u_k \\
# \end{align*}
# $$
# This is a Simple Sum,
#
# $$
# \begin{align*}
# \text{array} &= [a_1,a_2,...,a_n] \\
# \text{array prefix} &= [a_1, a_1+a_2, a_1+a_2+a_3,...]
# \end{align*}
# $$

# %% [markdown]
# Seperated Kappa,
#
# Intersection Over Union for a confusion matrix $Q = \{q_{i,j}\}$,
# $$
# \begin{align*}
# IOU_1 = \frac{q_{11}}{
#     \sum_{i=1}^C q_{i,1} + \sum_{j=1}^Cq_{1,j} - q_{1,1}
# }
# \end{align*}
# $$
#
# $$
# \begin{align*}
# IOU_2 = \frac{\sum_{i=2}^C\sum_{j=2}q_{i,j}}{
#     \sum_{i=1}^C\sum_{j=1}^C q_{i,j} -q_{1,1}
# }
# \end{align*}
# $$
# And,
# $$
# \begin{align*}
# mIOU = \frac{1}{2}(IOU_1+IOU_2)
# \end{align*}
# $$

# %% [markdown]
# $$
# \text{SeK} = e^{(\text{IOU}_{2}-1)} \cdot \frac{(\hat{\rho} - \hat{\eta})}{(1 - \hat{\eta})},
# $$
#
# $$
# \hat{\rho} = \frac{\sum\limits_{i=2}^{C} q_{ii}}{\sum\limits_{i=1}^{C} \sum\limits_{j=1}^{C} q_{ij} - q_{11}},
# $$
#
# $$
# \hat{\eta} = \frac{\sum\limits_{j=1}^{C} (\hat{q}_{j+} \cdot \hat{q}_{+j})}{\left(\sum_{i=1}^{C} \sum_{j=1}^{C} q_{ij} - q_{11}\right)^2},
# $$

# %% [markdown]
# # Dice Loss

# %% [markdown]
# # Visualizations of loss Function

# %%
import sys
import os
main_dir = os.path.dirname(os.getcwd())
sys.path.append(main_dir)

import argparse
import os
import time

import numpy as np

from MambaCD.changedetection.configs.config import get_config

import torch
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from tqdm import tqdm
from MambaCD.changedetection.datasets.make_data_loader import SemanticChangeDetectionDatset, make_data_loader
from MambaCD.changedetection.utils_func.metrics import Evaluator
from MambaCD.changedetection.models.STMambaSCD import STMambaSCD
import MambaCD.changedetection.utils_func.lovasz_loss as L
from torch.optim.lr_scheduler import StepLR

from MambaCD.changedetection.utils_func.mcd_utils import accuracy, SCDD_eval_all, AverageMeter
import matplotlib.pyplot as plt
# Out:
# /home/e19063/ChangeDetection-Buddhi/MambaCD/classification/models/vmamba.py:252: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd
# /home/e19063/ChangeDetection-Buddhi/MambaCD/classification/models/vmamba.py:260: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_bwd
# /home/e19063/ChangeDetection-Buddhi/MambaCD/classification/models/vmamba.py:275: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd
# /home/e19063/ChangeDetection-Buddhi/MambaCD/classification/models/vmamba.py:283: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_bwd
# /home/e19063/ChangeDetection-Buddhi/MambaCD/classification/models/vmamba.py:296: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd
# /home/e19063/ChangeDetection-Buddhi/MambaCD/classification/models/vmamba.py:304: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_bwd

# %%
torch.cuda.set_device(0)

# %%
MODEL_PATH = os.path.join(
    main_dir, "MambaCD/saved_models/SE/15000_model.pth"
)

# %%
configs_path = os.path.join(main_dir, 'MambaCD/changedetection/configs/vssm1/vssm_base_224.yaml')
VSSM_MODEL_PATH = os.path.join(
    main_dir, 'MambaCD/pretrained/vssm_base_0229_ckpt_epoch_237.pth'
)
model_path = os.path.join(main_dir, 'MambaCD/saved_models')

SECOND_DATASET_PATH = os.path.join(main_dir, 'Datasets', 'SECOND')
SECOND_TRAIN_DATASET_PATH = os.path.join(SECOND_DATASET_PATH, 'train')
SECOND_TEST_DATASET_PATH = os.path.join(SECOND_DATASET_PATH, 'test')
SECOND_TRAIN_DATA_LIST_PATH = os.path.join(SECOND_DATASET_PATH, 'train.txt')
SECOND_TEST_DATA_LIST_PATH = os.path.join(SECOND_DATASET_PATH, 'test.txt')

train_data_list = []
with open(SECOND_TRAIN_DATA_LIST_PATH, 'r') as f:
    for line in f:
        train_data_list.append(line.strip())

test_data_list = []
with open(SECOND_TEST_DATA_LIST_PATH, 'r') as f:
    for line in f:
        test_data_list.append(line.strip())

class ARGS:
    def __init__(self):
        self.cfg = configs_path
        self.opts = None
        self.pretrained_weight_path = MODEL_PATH
        self.dataset = 'SECOND'
        self.type = 'train'
        self.train_dataset_path = SECOND_TRAIN_DATASET_PATH
        self.train_data_list_path = SECOND_TRAIN_DATA_LIST_PATH
        self.test_dataset_path = SECOND_TEST_DATASET_PATH
        self.test_data_list_path = SECOND_TEST_DATA_LIST_PATH
        self.shuffle = False
        self.batch_size = 1
        self.crop_size = 256
        self.train_data_name_list = train_data_list
        self.test_data_name_list = test_data_list
        self.start_iter = 0
        self.cuda = True
        self.max_iters = 400000
        self.model_type = 'MambaSCD'
        self.model_param_path = model_path
        self.resume = None
        self.learning_rate = 1e-4
        self.momentum = 0.9
        self.weight_decay = 5e-4

args = ARGS()

# %%
args = args
config = get_config(args)

train_data_loader = make_data_loader(args)

deep_model = STMambaSCD(
    output_cd = 2, 
    output_clf = 7,
    pretrained=args.pretrained_weight_path,
    patch_size=config.MODEL.VSSM.PATCH_SIZE, 
    in_chans=config.MODEL.VSSM.IN_CHANS, 
    num_classes=config.MODEL.NUM_CLASSES, 
    depths=config.MODEL.VSSM.DEPTHS, 
    dims=config.MODEL.VSSM.EMBED_DIM, 
    # ===================
    ssm_d_state=config.MODEL.VSSM.SSM_D_STATE,
    ssm_ratio=config.MODEL.VSSM.SSM_RATIO,
    ssm_rank_ratio=config.MODEL.VSSM.SSM_RANK_RATIO,
    ssm_dt_rank=("auto" if config.MODEL.VSSM.SSM_DT_RANK == "auto" else int(config.MODEL.VSSM.SSM_DT_RANK)),
    ssm_act_layer=config.MODEL.VSSM.SSM_ACT_LAYER,
    ssm_conv=config.MODEL.VSSM.SSM_CONV,
    ssm_conv_bias=config.MODEL.VSSM.SSM_CONV_BIAS,
    ssm_drop_rate=config.MODEL.VSSM.SSM_DROP_RATE,
    ssm_init=config.MODEL.VSSM.SSM_INIT,
    forward_type=config.MODEL.VSSM.SSM_FORWARDTYPE,
    # ===================
    mlp_ratio=config.MODEL.VSSM.MLP_RATIO,
    mlp_act_layer=config.MODEL.VSSM.MLP_ACT_LAYER,
    mlp_drop_rate=config.MODEL.VSSM.MLP_DROP_RATE,
    # ===================
    drop_path_rate=config.MODEL.DROP_PATH_RATE,
    patch_norm=config.MODEL.VSSM.PATCH_NORM,
    norm_layer=config.MODEL.VSSM.NORM_LAYER,
    downsample_version=config.MODEL.VSSM.DOWNSAMPLE,
    patchembed_version=config.MODEL.VSSM.PATCHEMBED,
    gmlp=config.MODEL.VSSM.GMLP,
    use_checkpoint=config.TRAIN.USE_CHECKPOINT,
    ) 

deep_model.load_state_dict(torch.load(MODEL_PATH))
deep_model.cuda()
# Out:
# => merge config from /home/e19063/ChangeDetection-Buddhi/MambaCD/changedetection/configs/vssm1/vssm_base_224.yaml
# /home/e19063/ChangeDetection-Buddhi/MambaCD/changedetection/models/Mamba_backbone.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _ckpt = torch.load(open(ckpt, "rb"), map_location=torch.device("cpu"))
# Successfully load ckpt /home/e19063/ChangeDetection-Buddhi/MambaCD/saved_models/SE/15000_model.pth
# Failed loading checkpoint form /home/e19063/ChangeDetection-Buddhi/MambaCD/saved_models/SE/15000_model.pth: 'model'
# False
# /tmp/ipykernel_178907/3711684686.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   deep_model.load_state_dict(torch.load(MODEL_PATH))
# STMambaSCD(
#   (encoder): Backbone_VSSM(
#     (patch_embed): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): Permute()
#       (2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       (3): Permute()
#       (4): GELU(approximate='none')
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (6): Permute()
#       (7): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     )
#     (layers): ModuleList(
#       (0): Sequential(
#         (blocks): Sequential(
#           (0): VSSBlock(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=128, out_features=256, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#               (out_proj): Linear(in_features=256, out_features=128, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.0)
#             (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=128, out_features=512, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=512, out_features=128, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (1): VSSBlock(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=128, out_features=256, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#               (out_proj): Linear(in_features=256, out_features=128, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.030000001192092896)
#             (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=128, out_features=512, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=512, out_features=128, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (downsample): Sequential(
#           (0): Permute()
#           (1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (2): Permute()
#           (3): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (1): Sequential(
#         (blocks): Sequential(
#           (0): VSSBlock(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=256, out_features=512, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#               (out_proj): Linear(in_features=512, out_features=256, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.06000000238418579)
#             (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=256, out_features=1024, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=1024, out_features=256, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (1): VSSBlock(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=256, out_features=512, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#               (out_proj): Linear(in_features=512, out_features=256, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.09000000357627869)
#             (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=256, out_features=1024, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=1024, out_features=256, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (downsample): Sequential(
#           (0): Permute()
#           (1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (2): Permute()
#           (3): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (2): Sequential(
#         (blocks): Sequential(
#           (0): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.12000000476837158)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (1): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.15000000596046448)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (2): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.18000000715255737)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (3): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.21000000834465027)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (4): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.24000000953674316)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (5): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.27000001072883606)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (6): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.30000001192092896)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (7): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.33000001311302185)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (8): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.36000001430511475)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (9): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.39000001549720764)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (10): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.42000001668930054)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (11): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.45000001788139343)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (12): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.48000001907348633)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (13): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.5099999904632568)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (14): VSSBlock(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=512, out_features=1024, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#               (out_proj): Linear(in_features=1024, out_features=512, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.5400000214576721)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=512, out_features=2048, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=2048, out_features=512, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (downsample): Sequential(
#           (0): Permute()
#           (1): Conv2d(512, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (2): Permute()
#           (3): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (3): Sequential(
#         (blocks): Sequential(
#           (0): VSSBlock(
#             (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=1024, out_features=2048, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2048, bias=False)
#               (out_proj): Linear(in_features=2048, out_features=1024, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.5700000524520874)
#             (norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (1): VSSBlock(
#             (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (op): SS2D(
#               (out_norm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#               (in_proj): Linear(in_features=1024, out_features=2048, bias=False)
#               (act): SiLU()
#               (conv2d): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2048, bias=False)
#               (out_proj): Linear(in_features=2048, out_features=1024, bias=False)
#               (dropout): Identity()
#             )
#             (drop_path): timm.DropPath(0.6000000238418579)
#             (norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (downsample): Identity()
#       )
#     )
#     (outnorm0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (outnorm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (outnorm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (outnorm3): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder_bcd): ChangeDecoder(
#     (st_block_41): Sequential(
#       (0): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Permute()
#       (2): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Permute()
#     )
#     (st_block_42): Sequential(
#       (0): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Permute()
#       (2): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Permute()
#     )
#     (st_block_43): Sequential(
#       (0): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Permute()
#       (2): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Permute()
#     )
#     (st_block_31): Sequential(
#       (0): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Permute()
#       (2): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Permute()
#     )
#     (st_block_32): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Permute()
#       (2): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Permute()
#     )
#     (st_block_33): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Permute()
#       (2): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Permute()
#     )
#     (st_block_21): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Permute()
#       (2): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Permute()
#     )
#     (st_block_22): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Permute()
#       (2): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Permute()
#     )
#     (st_block_23): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Permute()
#       (2): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Permute()
#     )
#     (st_block_11): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Permute()
#       (2): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Permute()
#     )
#     (st_block_12): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Permute()
#       (2): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Permute()
#     )
#     (st_block_13): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Permute()
#       (2): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Permute()
#     )
#     (fuse_layer_4): Sequential(
#       (0): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (fuse_layer_3): Sequential(
#       (0): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (fuse_layer_2): Sequential(
#       (0): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (fuse_layer_1): Sequential(
#       (0): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (smooth_layer_3): ResBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (smooth_layer_2): ResBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (smooth_layer_1): ResBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (decoder_T1): SemanticDecoder(
#     (st_block_4_semantic): Sequential(
#       (0): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Permute()
#       (2): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Permute()
#     )
#     (st_block_3_semantic): Sequential(
#       (0): Permute()
#       (1): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): Permute()
#     )
#     (st_block_2_semantic): Sequential(
#       (0): Permute()
#       (1): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): Permute()
#     )
#     (st_block_1_semantic): Sequential(
#       (0): Permute()
#       (1): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): Permute()
#     )
#     (trans_layer_3): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): SqueezeExcitation(
#         (squeeze): AdaptiveAvgPool2d(output_size=1)
#         (excitation): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#       (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#     )
#     (trans_layer_2): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): SqueezeExcitation(
#         (squeeze): AdaptiveAvgPool2d(output_size=1)
#         (excitation): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#       (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#     )
#     (trans_layer_1): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): SqueezeExcitation(
#         (squeeze): AdaptiveAvgPool2d(output_size=1)
#         (excitation): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#       (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#     )
#     (smooth_layer_3_semantic): ResBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SqueezeExcitation(
#         (squeeze): AdaptiveAvgPool2d(output_size=1)
#         (excitation): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (smooth_layer_2_semantic): ResBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SqueezeExcitation(
#         (squeeze): AdaptiveAvgPool2d(output_size=1)
#         (excitation): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (smooth_layer_1_semantic): ResBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SqueezeExcitation(
#         (squeeze): AdaptiveAvgPool2d(output_size=1)
#         (excitation): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (smooth_layer_0_semantic): ResBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SqueezeExcitation(
#         (squeeze): AdaptiveAvgPool2d(output_size=1)
#         (excitation): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (decoder_T2): SemanticDecoder(
#     (st_block_4_semantic): Sequential(
#       (0): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Permute()
#       (2): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): Permute()
#     )
#     (st_block_3_semantic): Sequential(
#       (0): Permute()
#       (1): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): Permute()
#     )
#     (st_block_2_semantic): Sequential(
#       (0): Permute()
#       (1): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): Permute()
#     )
#     (st_block_1_semantic): Sequential(
#       (0): Permute()
#       (1): VSSBlock(
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (op): SS2D(
#           (out_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (in_proj): Linear(in_features=128, out_features=256, bias=False)
#           (act): SiLU()
#           (conv2d): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (out_proj): Linear(in_features=256, out_features=128, bias=False)
#           (dropout): Identity()
#         )
#         (drop_path): timm.DropPath(0.1)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=512, out_features=128, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): Permute()
#     )
#     (trans_layer_3): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): SqueezeExcitation(
#         (squeeze): AdaptiveAvgPool2d(output_size=1)
#         (excitation): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#       (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#     )
#     (trans_layer_2): Sequential(
#       (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): SqueezeExcitation(
#         (squeeze): AdaptiveAvgPool2d(output_size=1)
#         (excitation): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#       (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#     )
#     (trans_layer_1): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): SqueezeExcitation(
#         (squeeze): AdaptiveAvgPool2d(output_size=1)
#         (excitation): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#       (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#     )
#     (smooth_layer_3_semantic): ResBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SqueezeExcitation(
#         (squeeze): AdaptiveAvgPool2d(output_size=1)
#         (excitation): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (smooth_layer_2_semantic): ResBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SqueezeExcitation(
#         (squeeze): AdaptiveAvgPool2d(output_size=1)
#         (excitation): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (smooth_layer_1_semantic): ResBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SqueezeExcitation(
#         (squeeze): AdaptiveAvgPool2d(output_size=1)
#         (excitation): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (smooth_layer_0_semantic): ResBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SqueezeExcitation(
#         (squeeze): AdaptiveAvgPool2d(output_size=1)
#         (excitation): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (change_attention_1): MultiScaleChangeGuidedAttention(
#     (conv_layers): ModuleList(
#       (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#       (3): Conv2d(128, 1024, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (change_attention_2): MultiScaleChangeGuidedAttention(
#     (conv_layers): ModuleList(
#       (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#       (3): Conv2d(128, 1024, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (main_clf_cd): Conv2d(128, 2, kernel_size=(1, 1), stride=(1, 1))
#   (aux_clf): Conv2d(128, 7, kernel_size=(1, 1), stride=(1, 1))
# )

# %% [markdown]
# # Image Lib

# %%
ori_label_value_dict = {
    'background': (0, 0, 0),
    'low_vegetation': (0, 128, 0),
    'nvg_surface': (128, 128, 128),
    'tree': (0, 255, 0),
    'water': (0, 0, 255),
    'Building': (128, 0, 0),
    'Playground': (255, 0, 0)
}

target_label_value_dict = {
    'background': 0,
    'low_vegetation': 1,
    'nvg_surface': 2,
    'tree': 3,
    'water': 4,
    'Building': 5,
    'Playground': 6
}

def map_labels_to_colors(labels, ori_label_value_dict, target_label_value_dict):
    # Reverse the target_label_value_dict to get a mapping from target labels to original labels
    target_to_ori = {v: k for k, v in target_label_value_dict.items()}
    
    # Initialize an empty 3D array for the color-mapped labels
    H, W = labels.shape
    color_mapped_labels = np.zeros((H, W, 3), dtype=np.uint8)
    
    for target_label, ori_label in target_to_ori.items():
        # Find where the label matches the current target label
        mask = labels == target_label
        
        # Map these locations to the corresponding color value
        color_mapped_labels[mask] = ori_label_value_dict[ori_label]
    
    return color_mapped_labels

# %%
def get_first_batch():
    return next(iter(train_data_loader))

data = get_first_batch()

# %%
pre_change_imgs, post_change_imgs, label_cd, label_clf_t1, label_clf_t2, _ = data

pre_change_imgs = pre_change_imgs.cuda()
post_change_imgs = post_change_imgs.cuda()
label_cd = label_cd.cuda().long()
label_clf_t1 = label_clf_t1.cuda().long()
label_clf_t2 = label_clf_t2.cuda().long()

change_map_T1 = map_labels_to_colors(np.squeeze(label_clf_t1.cpu().numpy()), ori_label_value_dict=ori_label_value_dict, target_label_value_dict=target_label_value_dict)
change_map_T2 = map_labels_to_colors(np.squeeze(label_clf_t2.cpu().numpy()), ori_label_value_dict=ori_label_value_dict, target_label_value_dict=target_label_value_dict)

fig1, axes = plt.subplots(1, 5, figsize=(12, 4))
axes[0].imshow(label_cd[0].cpu().numpy(), cmap='gray')
axes[0].set_title('Label Change Detection')
axes[1].imshow(change_map_T1)
axes[1].set_title('Change Map T1')
axes[2].imshow(change_map_T2)
axes[2].set_title('Change Map T2')
axes[3].imshow(label_clf_t1[0].cpu().numpy())
axes[3].set_title('Label Classification T1')
axes[4].imshow(label_clf_t2[0].cpu().numpy())
axes[4].set_title('Label Classification T2')
plt.show()

# %%
label_clf_t1[label_clf_t1 == 0] = 255
label_clf_t2[label_clf_t2 == 0] = 255

change_map_T1 = map_labels_to_colors(np.squeeze(label_clf_t1.cpu().numpy()), ori_label_value_dict=ori_label_value_dict, target_label_value_dict=target_label_value_dict)
change_map_T2 = map_labels_to_colors(np.squeeze(label_clf_t2.cpu().numpy()), ori_label_value_dict=ori_label_value_dict, target_label_value_dict=target_label_value_dict)

fig1, axes = plt.subplots(1, 5, figsize=(12, 4))
axes[0].imshow(label_cd[0].cpu().numpy(), cmap='gray')
axes[0].set_title('Label Change Detection')
axes[1].imshow(change_map_T1)
axes[1].set_title('Label Classification T1')
axes[2].imshow(change_map_T2)
axes[2].set_title('Label Classification T2')
axes[3].imshow(label_clf_t1[0].cpu().numpy())
axes[3].set_title('Label Classification T1')
axes[4].imshow(label_clf_t2[0].cpu().numpy())
axes[4].set_title('Label Classification T2')
plt.show()

# %%
output_1, output_semantic_t1_, output_semantic_t2_ = deep_model(pre_change_imgs, post_change_imgs)

# %%
output_semantic_t1 = output_semantic_t1_.clone()
output_semantic_t2 = output_semantic_t2_.clone()

# %%
label_out_cd = output_1.clone()
label_out_cd = torch.argmax(label_out_cd, dim=1)

label_out_clf_t1 = output_semantic_t1.clone()
label_out_clf_t1 = torch.argmax(label_out_clf_t1, dim=1)

label_out_clf_t2 = output_semantic_t2.clone()
label_out_clf_t2 = torch.argmax(label_out_clf_t2, dim=1)


label_out_clf_t1 = map_labels_to_colors(np.squeeze(label_out_clf_t1.cpu().numpy()), ori_label_value_dict=ori_label_value_dict, target_label_value_dict=target_label_value_dict)
label_out_clf_t2 = map_labels_to_colors(np.squeeze(label_out_clf_t2.cpu().numpy()), ori_label_value_dict=ori_label_value_dict, target_label_value_dict=target_label_value_dict)

fig1, axes = plt.subplots(1, 5, figsize=(12, 4))
axes[0].imshow(label_out_cd[0].cpu().numpy(), cmap='gray')
axes[0].set_title('Label Change Detection')
axes[1].imshow(label_out_clf_t1)
axes[1].set_title('Label Classification T1')
axes[2].imshow(label_out_clf_t2)
axes[2].set_title('Label Classification T2')
axes[3].imshow(pre_change_imgs[0].cpu().numpy().transpose(1, 2, 0))
axes[3].set_title('Pre Change Image')
axes[4].imshow(post_change_imgs[0].cpu().numpy().transpose(1, 2, 0))
axes[4].set_title('Post Change Image')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.1246682..2.4308498].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9306723..2.64].

# %% [markdown]
# # Evaluation

# %%
dataset = SemanticChangeDetectionDatset(args.test_dataset_path, args.test_data_name_list, 256, None, 'test')
val_data_loader = DataLoader(dataset, batch_size=8, num_workers=4, drop_last=False)
torch.cuda.empty_cache()
acc_meter = AverageMeter()

preds_all = []
labels_all = []
with torch.no_grad():
    for itera, data in enumerate(val_data_loader):
        pre_change_imgs, post_change_imgs, labels_cd, labels_clf_t1, labels_clf_t2, _ = data

        pre_change_imgs = pre_change_imgs.cuda()
        post_change_imgs = post_change_imgs.cuda()
        labels_cd = labels_cd.cuda().long()
        labels_clf_t1 = labels_clf_t1.cuda().long()
        labels_clf_t2 = labels_clf_t2.cuda().long()


        # input_data = torch.cat([pre_change_imgs, post_change_imgs], dim=1)
        output_1, output_semantic_t1, output_semantic_t2 = deep_model(pre_change_imgs, post_change_imgs)

        labels_cd = labels_cd.cpu().numpy()
        labels_A = labels_clf_t1.cpu().numpy()
        labels_B = labels_clf_t2.cpu().numpy()

        change_mask = torch.argmax(output_1, axis=1).cpu().numpy()

        preds_A = torch.argmax(output_semantic_t1, dim=1).cpu().numpy()
        preds_B = torch.argmax(output_semantic_t2, dim=1).cpu().numpy()

        preds_A[change_mask == 0] = 0
        preds_B[change_mask == 0] = 0

        if itera % 100 == 0:
            print(f'iter is {itera}')

        for (pred_A, pred_B, label_A, label_B) in zip(preds_A, preds_B, labels_A, labels_B):
            acc_A, valid_sum_A = accuracy(pred_A, label_A)
            acc_B, valid_sum_B = accuracy(pred_B, label_B)
            preds_all.append(pred_A)
            preds_all.append(pred_B)
            labels_all.append(label_A)
            labels_all.append(label_B)
            acc = (acc_A + acc_B) * 0.5
            acc_meter.update(acc)

kappa_n0, Fscd, IoU_mean, Sek = SCDD_eval_all(preds_all, labels_all, 37)
print(f'Kappa coefficient rate is {kappa_n0}, F1 is {Fscd}, OA is {acc_meter.avg}, '
        f'mIoU is {IoU_mean}, SeK is {Sek}')
# Out:
# iter is 0
# iter is 100
# Kappa coefficient rate is 0.3540291823048794, F1 is 0.6374527267513668, OA is 0.8766338935560383, mIoU is 0.7281591574684411, SeK is 0.23226869356230073

# %%
dataset = SemanticChangeDetectionDatset(args.test_dataset_path, args.test_data_name_list, 256, None, 'test')
val_data_loader = DataLoader(dataset, batch_size=4, num_workers=4, drop_last=False)
torch.cuda.empty_cache()
acc_meter = AverageMeter()

preds_all = []
labels_all = []
with torch.no_grad():
    for itera, data in enumerate(val_data_loader):
        pre_change_imgs, post_change_imgs, labels_cd, labels_clf_t1, labels_clf_t2, _ = data

        pre_change_imgs = pre_change_imgs.cuda()
        post_change_imgs = post_change_imgs.cuda()
        labels_cd = labels_cd.cuda().long()
        labels_clf_t1 = labels_clf_t1.cuda().long()
        labels_clf_t2 = labels_clf_t2.cuda().long()


        # input_data = torch.cat([pre_change_imgs, post_change_imgs], dim=1)
        output_1, output_semantic_t1, output_semantic_t2 = deep_model(pre_change_imgs, post_change_imgs)

        labels_cd = labels_cd.cpu().numpy()
        labels_A = labels_clf_t1.cpu().numpy()
        labels_B = labels_clf_t2.cpu().numpy()

        change_mask = torch.argmax(output_1, axis=1).cpu().numpy()

        preds_A = torch.argmax(output_semantic_t1, dim=1).cpu().numpy()
        preds_B = torch.argmax(output_semantic_t2, dim=1).cpu().numpy()
        

        preds_scd = (preds_A - 1) * 6 + preds_B
        preds_scd[change_mask == 0] = 0

        labels_scd = (labels_A - 1) * 6 + labels_B
        labels_scd[labels_cd == 0] = 0

        for (pred_scd, label_scd) in zip(preds_scd, labels_scd):
            acc_A, valid_sum_A = accuracy(pred_scd, label_scd)
            preds_all.append(pred_scd)
            labels_all.append(label_scd)
            acc = acc_A
            acc_meter.update(acc)

kappa_n0, Fscd, IoU_mean, Sek = SCDD_eval_all(preds_all, labels_all, 37)
print(f'Kappa coefficient rate is {kappa_n0}, F1 is {Fscd}, OA is {acc_meter.avg}, '
        f'mIoU is {IoU_mean}, SeK is {Sek}')
# Out:
# Kappa coefficient rate is 0.3389363509299535, F1 is 0.5534750904780753, OA is 0.8606832991663358, mIoU is 0.7287604735952544, SeK is 0.22249582954378633
