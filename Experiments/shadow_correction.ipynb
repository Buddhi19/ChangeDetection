# %%
import os
import sys

main_path = os.path.dirname(os.getcwd())
sys.path.append(main_path)
print(main_path)
# Out:
# d:\PROJECTS\ChangeDetection\CD

# %%
from SID.src.infer import Predict
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from SID.src.infer import Predict
#
# File d:\PROJECTS\ChangeDetection\CD\SID\src\infer.py:5
#       3 import torch
#       4 import os
# ----> 5 from options.test_options import TestOptions
#       6 from models import create_model
#       7 from data.single_dataset import SingleDataset
#
# ModuleNotFoundError: No module named 'options'
